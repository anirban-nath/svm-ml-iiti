# %%
import pandas as pd
df = pd.read_csv("spambase.csv")
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %%
from sklearn.metrics import accuracy_score
from sklearn import svm
c_values = [1.0,2.0,5.0,10.0,20.0]

acc_score_linear = []

for c_value in c_values:
    classifier = svm.SVC(C = c_value, kernel = 'linear', random_state = 42)
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    acc_score_linear.append(accuracy_score(y_test, y_pred))

# %%
print(acc_score_linear)
# Out:
# [0.9217391304347826, 0.9210144927536232, 0.913768115942029, 0.9108695652173913, 0.9101449275362319]

# %%
acc_score_rbf = []

for c_value in c_values:
    classifier = SVC(C = c_value, kernel = 'rbf', random_state = 42)
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    acc_score_rbf.append(accuracy_score(y_test, y_pred))

# %%
print(acc_score_rbf)
# Out:
# [0.7086956521739131, 0.7246376811594203, 0.736231884057971, 0.741304347826087, 0.7543478260869565]

# %%
acc_score_quadratic = []

for c_value in c_values:
    classifier = SVC(C = c_value, kernel = 'poly', random_state = 42)
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    acc_score_quadratic.append(accuracy_score(y_test, y_pred))

# %%
print(acc_score_quadratic)
# Out:
# [0.6521739130434783, 0.6528985507246376, 0.6579710144927536, 0.6601449275362319, 0.6652173913043479]

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1.5])
values = ['1.0', '2.0', '5.0', '10.0', '20.0']
ax.bar(values,acc_score_linear)
plt.ylim(min(acc_score_linear)-0.01, max(acc_score_linear)+0.01)
plt.title("C Value vs Accuracy for SVM using Linear Kernel")
plt.xlabel("C Value")
plt.ylabel("Accuracy")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1.5])
values = ['1.0', '2.0', '5.0', '10.0', '20.0']
ax.bar(values,acc_score_rbf)
plt.ylim(min(acc_score_rbf)-0.01, max(acc_score_rbf)+0.01)
plt.title("C Value vs Accuracy for SVM using RBF Kernel")
plt.xlabel("C Value")
plt.ylabel("Accuracy")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1.5])
values = ['1.0', '2.0', '5.0', '10.0', '20.0']
ax.bar(values,acc_score_quadratic)
plt.ylim(min(acc_score_quadratic)-0.01, max(acc_score_quadratic)+0.01)
plt.title("C Value vs Accuracy for SVM using Polynomial Kernel")
plt.xlabel("C Value")
plt.ylabel("Accuracy")
plt.show()
